# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = pd.read_csv('baselines/dehnn_5_3_16_True_False_2025-01-22_20-11-25_baseline.csv')
results
# Out:
#    Epoch  Node_Train_Loss  Net_Train_Loss  Node_Valid_Loss  Net_Valid_Loss  \
# 0      1         1.006034        1.010190         1.001559        1.001363
# 1      2         1.000326        0.999241         0.998057        0.998701
# 2      3         0.998789        0.994568         0.998388        0.999949
# 3      4         0.998322        0.992027         0.999350        1.000235
# 4      5         0.998138        0.990170         0.997537        0.996902
#
#      Time
# 0   41.45
# 1   84.68
# 2  125.42
# 3  166.40
# 4  207.71

# %%
plt.plot(results['Epoch'], results['Node_Valid_Loss'], label='Validation Loss')
plt.plot(results['Epoch'], results['Node_Train_Loss'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Node Loss')
plt.legend()
plt.show()

# %%
results.columns
# Out:
# Index(['Epoch', ' Node_Train_Loss', ' Net_Train_Loss', ' Node_Valid_Loss',
#        ' Net_Valid_Loss', ' Time'],
#       dtype='object')
