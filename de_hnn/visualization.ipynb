# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = pd.read_csv('baselines/dehnn_500_2_16_True_False_2025-02-02_23-26-08_classify.csv')
results
# Out:
#      Epoch      tp      fp     tn     fn         p         r       fsc  \
# 0        1  480344  420910      0      0  0.532973  1.000000  0.695346
# 1        2  480344  420910      0      0  0.532973  1.000000  0.695346
# 2        3  480344  420910      0      0  0.532973  1.000000  0.695346
# 3        4  480344  420910      0      0  0.532973  1.000000  0.695346
# 4        5  480344  420910      0      0  0.532973  1.000000  0.695346
# ..     ...     ...     ...    ...    ...       ...       ...       ...
# 198    199  473323  410404  10506   7021  0.535599  0.985383  0.693986
# 199    200  453242  396665  24245  27102  0.533284  0.943578  0.681438
# 200    201  471227  409405  11505   9117  0.535101  0.981020  0.692484
# 201    202  462556  399747  21163  17788  0.536419  0.962968  0.689021
# 202    203  470298  408741  12169  10046  0.535014  0.979086  0.691929
#
#             m     Time
# 0    1.000000    36.60
# 1    1.000000   108.64
# 2    1.000000   139.64
# 3    1.000000   170.59
# 4    1.000000   201.15
# ..        ...      ...
# 198  0.980553  6214.84
# 199  0.943027  6245.74
# 200  0.977119  6276.19
# 201  0.956781  6306.71
# 202  0.975351  6337.47
#
# [203 rows x 10 columns]

# %%
plt.plot(results['Epoch'], results['fsc'])

# %%
plt.plot(results['Epoch'], results['Node_Valid_Loss'], label='Validation Loss')
plt.plot(results['Epoch'], results['Node_Train_Loss'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Node Loss')
plt.legend()
plt.show()

# %%
plt.plot(results['Epoch'], results['Net_Valid_Loss'], label='Validation Loss')
plt.plot(results['Epoch'], results['Net_Train_Loss'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Net Loss')
plt.legend()
plt.show()
