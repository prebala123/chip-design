# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = pd.read_csv('baselines/dehnn_50_3_16_True_False_2025-01-27_22-27-11_baseline.csv')
results
# Out:
#     Epoch  Node_Train_Loss  Net_Train_Loss  Node_Valid_Loss  Net_Valid_Loss  \
# 0       1         0.675157        0.715691         0.676385        0.715596
# 1       2         0.668274        0.722684         0.679650        0.712924
# 2       3         0.666363        0.718439         0.677590        0.708994
# 3       4         0.667340        0.720108         0.679323        0.718030
# 4       5         0.666846        0.732756         0.675633        0.724945
# 5       6         0.665114        0.740455         0.676211        0.726377
# 6       7         0.664138        0.732060         0.678705        0.715172
# 7       8         0.664374        0.724094         0.676199        0.709230
# 8       9         0.665668        0.720150         0.674693        0.709971
# 9      10         0.665601        0.724562         0.679879        0.722942
# 10     11         0.663913        0.739793         0.679507        0.727625
# 11     12         0.663539        0.737237         0.678976        0.717315
# 12     13         0.666965        0.724670         0.676470        0.705715
# 13     14         0.666594        0.727715         0.674790        0.733317
# 14     15         0.663127        0.749575         0.677059        0.731914
# 15     16         0.662810        0.741207         0.679409        0.712613
# 16     17         0.664035        0.724227         0.678962        0.713406
# 17     18         0.663649        0.736845         0.680175        0.728028
#
#       Time
# 0    90.74
# 1   153.74
# 2   208.60
# 3   258.17
# 4   300.43
# 5   345.13
# 6   395.36
# 7   450.45
# 8   500.04
# 9   544.91
# 10  595.28
# 11  648.97
# 12  692.42
# 13  746.59
# 14  830.59
# 15  875.58
# 16  919.90
# 17  971.77

# %%
plt.plot(results['Epoch'], results['Node_Valid_Loss'], label='Validation Loss')
plt.plot(results['Epoch'], results['Node_Train_Loss'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Node Loss')
plt.legend()
plt.show()

# %%
plt.plot(results['Epoch'], results['Net_Valid_Loss'], label='Validation Loss')
plt.plot(results['Epoch'], results['Net_Train_Loss'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Net Loss')
plt.legend()
plt.show()
