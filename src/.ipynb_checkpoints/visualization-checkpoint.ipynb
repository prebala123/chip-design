# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
results = pd.read_csv('../results/baselines/2025-02-12_11-57-54_2_16_True_demand_baseline.csv')
results
# Out:
#       Epoch  NodeTrain  NetTrain  NodeValid  NetValid     Time
# 0         1   4.516841  4.920819   1.100990  1.311721     4.30
# 1         2   4.514731  4.631790   1.445748  1.209663     8.10
# 2         3   4.335050  4.507315   1.353691  1.360038    11.44
# 3         4   4.375332  4.510538   1.248414  1.650039    15.72
# 4         5   4.340615  4.439664   1.380082  1.638420    18.84
# ...     ...        ...       ...        ...       ...      ...
# 1495   1496   2.068582  3.615550   1.818653  2.202220  5374.35
# 1496   1497   2.066930  3.515922   1.958202  2.291451  5377.76
# 1497   1498   2.064659  3.685605   1.924514  2.194018  5381.12
# 1498   1499   2.063325  3.747849   1.966304  2.173066  5384.90
# 1499   1500   2.057544  3.710896   1.934880  2.203566  5388.06
#
# [1500 rows x 6 columns]

# %%
plt.plot(results['NetValid'])

# %%
results['NetValid'].mean()
# Out:
# 2.2777590018908183

# %%
plt.plot(results['Epoch'], results['NodeValid'], label='Validation Loss')
plt.plot(results['Epoch'], results['NodeTrain'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Node Loss')
plt.legend()
plt.show()

# %%
plt.plot(results['Epoch'], results['NetValid'], label='Validation Loss')
plt.plot(results['Epoch'], results['NetTrain'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Net Loss')
plt.legend()
plt.show()
