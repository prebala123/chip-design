# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = pd.read_csv('../results/baselines/2025-02-04_01-07-09__10_2_16_True_demand_baseline.csv')
results
# Out:
#    Epoch  NodeTrain  NetTrain  NodeValid  NetValid    Time
# 0      1   1.002737  1.001841   0.995492  1.002367   27.54
# 1      2   1.000158  0.998312   0.997396  1.001709   60.46
# 2      3   0.998705  0.993782   0.997713  0.999180   93.17
# 3      4   0.997165  0.988731   0.996663  1.004177  122.59
# 4      5   0.996092  0.982818   1.001844  0.997596  152.47
# 5      6   0.993771  0.974986   1.009081  0.994566  183.34
# 6      7   0.993782  0.963224   1.015510  0.981621  212.84
# 7      8   0.993295  0.948852   1.014130  0.974279  243.71
# 8      9   0.991876  0.927907   1.019965  0.943036  273.84
# 9     10   0.993882  0.919176   1.024189  0.943556  305.04

# %%
plt.plot(results['Epoch'], results['NetValid'])

# %%
plt.plot(results['Epoch'], results['Node_Valid_Loss'], label='Validation Loss')
plt.plot(results['Epoch'], results['Node_Train_Loss'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Node Loss')
plt.legend()
plt.show()

# %%
plt.plot(results['Epoch'], results['Net_Valid_Loss'], label='Validation Loss')
plt.plot(results['Epoch'], results['Net_Train_Loss'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Net Loss')
plt.legend()
plt.show()
