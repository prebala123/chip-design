# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = pd.read_csv('../results/baselines/2025-02-04_19-36-51__200_2_16_True_congestion_baseline.csv')
results
# Out:
#      Epoch  TruePositive  FalsePositive  TrueNegative  FalseNegative  \
# 0        1        280163         179332             0              0
# 1        2        280163         179332             0              0
# 2        3        280163         179332             0              0
# 3        4        280163         179332             0              0
# 4        5        280163         179332             0              0
# ..     ...           ...            ...           ...            ...
# 195    196        216840         148989         30343          63323
# 196    197        181602         128213         51119          98561
# 197    198        239468         161134         18198          40695
# 198    199        222962         148595         30737          57201
# 199    200        209501         137238         42094          70662
#
#      Precision    Recall    Fscore  NodeTrain  NetTrain  NodeValid  NetValid  \
# ...

# %%
plt.plot(results['Epoch'], results['Fscore'])

# %%
plt.plot(results['Epoch'], results['Node_Valid_Loss'], label='Validation Loss')
plt.plot(results['Epoch'], results['Node_Train_Loss'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Node Loss')
plt.legend()
plt.show()

# %%
plt.plot(results['Epoch'], results['Net_Valid_Loss'], label='Validation Loss')
plt.plot(results['Epoch'], results['Net_Train_Loss'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Net Loss')
plt.legend()
plt.show()
