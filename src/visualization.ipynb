# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = pd.read_csv('../results/baselines/2025-02-06_23-40-02_2_16_True_demand_baseline.csv')
results
# Out:
#      Epoch  NodeTrain  NetTrain  NodeValid  NetValid     Time
# 0        1   1.124633  1.253697   0.372813  0.248383     3.73
# 1        2   1.121910  1.247940   0.388307  0.247943     7.36
# 2        3   1.115805  1.243772   0.394836  0.247925    10.44
# 3        4   1.114540  1.240803   0.403540  0.247872    14.21
# 4        5   1.112980  1.237882   0.410718  0.248220    17.99
# ..     ...        ...       ...        ...       ...      ...
# 495    496   0.752897  1.064501   0.649446  0.656537  1672.14
# 496    497   0.757458  1.064487   0.649169  0.647879  1675.28
# 497    498   0.760595  1.064821   0.644289  0.677871  1678.56
# 498    499   0.761008  1.064531   0.654575  0.669368  1681.53
# 499    500   0.756051  1.064526   0.661163  0.654147  1684.63
#
# [500 rows x 6 columns]

# %%
plt.plot(results['NetValid'])

# %%
results['NetValid'].mean()
# Out:
# 0.5601174236536026

# %%
plt.plot(results['Epoch'], results['NodeValid'], label='Validation Loss')
plt.plot(results['Epoch'], results['NodeTrain'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Node Loss')
plt.legend()
plt.show()

# %%
plt.plot(results['Epoch'], results['NetValid'], label='Validation Loss')
plt.plot(results['Epoch'], results['NetTrain'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Net Loss')
plt.legend()
plt.show()
