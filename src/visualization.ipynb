# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
results = pd.read_csv('../results/baselines/200_3_16_True_demand_baseline.csv')
results
# Out:
#      Epoch  NodeTrain  NetTrain  NodeValid  NetValid    Time
# 0        1   1.100453  1.242625   0.484445  0.258953    4.98
# 1        2   1.070871  1.223006   0.423514  0.257456   11.12
# 2        3   1.071899  1.215521   0.411110  0.287953   17.26
# 3        4   1.074586  1.209748   0.443989  0.328119   22.79
# 4        5   1.068169  1.200598   0.468209  0.361156   27.45
# ..     ...        ...       ...        ...       ...     ...
# 114    115   0.882454  1.065087   0.524444  0.557090  584.40
# 115    116   0.889960  1.062840   0.620585  0.486977  590.29
# 116    117   0.899566  1.063379   0.450971  0.634775  595.08
# 117    118   0.895504  1.063788   0.601229  0.556996  601.14
# 118    119   0.885631  1.061750   0.553005  0.501714  605.72
#
# [119 rows x 6 columns]

# %%
plt.plot(results['Epoch'], results['NetValid'])

# %%
plt.plot(results['Epoch'], results['NodeValid'], label='Validation Loss')
plt.plot(results['Epoch'], results['NodeTrain'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Node Loss')
plt.legend()
plt.show()

# %%
plt.plot(results['Epoch'], results['NetValid'], label='Validation Loss')
plt.plot(results['Epoch'], results['NetTrain'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Net Loss')
plt.legend()
plt.show()
